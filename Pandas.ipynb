# %%
# !pip install pandas
# Out:
# ...
# [notice] A new release of pip is available: 23.0 -> 23.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# import pandas

import pandas as pd

# %%
type(pd)
# Out:
# module

# %%
print(dir(pd))
# Out:
# ['ArrowDtype', 'BooleanDtype', 'Categorical', 'CategoricalDtype', 'CategoricalIndex', 'DataFrame', 'DateOffset', 'DatetimeIndex', 'DatetimeTZDtype', 'ExcelFile', 'ExcelWriter', 'Flags', 'Float32Dtype', 'Float64Dtype', 'Float64Index', 'Grouper', 'HDFStore', 'Index', 'IndexSlice', 'Int16Dtype', 'Int32Dtype', 'Int64Dtype', 'Int64Index', 'Int8Dtype', 'Interval', 'IntervalDtype', 'IntervalIndex', 'MultiIndex', 'NA', 'NaT', 'NamedAgg', 'Period', 'PeriodDtype', 'PeriodIndex', 'RangeIndex', 'Series', 'SparseDtype', 'StringDtype', 'Timedelta', 'TimedeltaIndex', 'Timestamp', 'UInt16Dtype', 'UInt32Dtype', 'UInt64Dtype', 'UInt64Index', 'UInt8Dtype', '__all__', '__builtins__', '__cached__', '__deprecated_num_index_names', '__dir__', '__doc__', '__docformat__', '__file__', '__getattr__', '__git_version__', '__loader__', '__name__', '__package__', '__path__', '__spec__', '__version__', '_config', '_is_numpy_dev', '_libs', '_testing', '_typing', '_version', 'annotations', 'api', 'array', 'arrays', '
# ...

# %%
# array
import numpy as np

# %%
lst = [
    [1,2,3,4],
    [2,3,6,4],
    [9,7,8,6]
]

# %%
data = np.array(lst)

# %%
data
# Out:
# array([[1, 2, 3, 4],
#        [2, 3, 6, 4],
#        [9, 7, 8, 6]])

# %%
data.shape
# Out:
# (3, 4)

# %%
# DataFrame

type(pd.DataFrame)
# Out:
# type

# %%
print(pd.DataFrame.__doc__)
# Out:
#     Two-dimensional, size-mutable, potentially heterogeneous tabular data.
#
#     Data structure also contains labeled axes (rows and columns).
#     Arithmetic operations align on both row and column labels. Can be
#     thought of as a dict-like container for Series objects. The primary
#     pandas data structure.
#
#     Parameters
#     ----------
#     data : ndarray (structured or homogeneous), Iterable, dict, or DataFrame
#         Dict can contain Series, arrays, constants, dataclass or list-like objects. If
#         data is a dict, column order follows insertion-order. If a dict contains Series
#         which have an index defined, it is aligned by its index.
#
#         .. versionchanged:: 0.25.0
#            If data is a list of dicts, column order follows insertion-order.
#
#     index : Index or array-like
#         Index to use for resulting frame. Will default to RangeIndex if
#         no indexing information part of input data and no index provided.
# ...

# %%
pd.DataFrame(data=data)
# Out:
#    0  1  2  3
# 0  1  2  3  4
# 1  2  3  6  4
# 2  9  7  8  6

# %%
pd.DataFrame(data=data, index=[0,1,2])
# Out:
#    0  1  2  3
# 0  1  2  3  4
# 1  2  3  6  4
# 2  9  7  8  6

# %%
pd.DataFrame(data=data, columns=['Col 1', 'Col 2', 'Col 3', 'Col 4'])
# Out:
#    Col 1  Col 2  Col 3  Col 4
# 0      1      2      3      4
# 1      2      3      6      4
# 2      9      7      8      6

# %%
pd.DataFrame(data=data, columns=['Col 1', 'Col 2', 'Col 3', 'Col 4'], index=['Row 1', 'Row 2', 'Row 3'])
# Out:
#        Col 1  Col 2  Col 3  Col 4
# Row 1      1      2      3      4
# Row 2      2      3      6      4
# Row 3      9      7      8      6

# %%
df = pd.DataFrame(data=data, columns=['Col 1', 'Col 2', 'Col 3', 'Col 4'], index=['Row 1', 'Row 2', 'Row 3'])

# %%
df
# Out:
#        Col 1  Col 2  Col 3  Col 4
# Row 1      1      2      3      4
# Row 2      2      3      6      4
# Row 3      9      7      8      6

# %%
print(dir(df))
# Out:
# ['T', '_AXIS_LEN', '_AXIS_ORDERS', '_AXIS_TO_AXIS_NUMBER', '_HANDLED_TYPES', '__abs__', '__add__', '__and__', '__annotations__', '__array__', '__array_priority__', '__array_ufunc__', '__array_wrap__', '__bool__', '__class__', '__contains__', '__copy__', '__dataframe__', '__deepcopy__', '__delattr__', '__delitem__', '__dict__', '__dir__', '__divmod__', '__doc__', '__eq__', '__finalize__', '__floordiv__', '__format__', '__ge__', '__getattr__', '__getattribute__', '__getitem__', '__getstate__', '__gt__', '__hash__', '__iadd__', '__iand__', '__ifloordiv__', '__imod__', '__imul__', '__init__', '__init_subclass__', '__invert__', '__ior__', '__ipow__', '__isub__', '__iter__', '__itruediv__', '__ixor__', '__le__', '__len__', '__lt__', '__matmul__', '__mod__', '__module__', '__mul__', '__ne__', '__neg__', '__new__', '__nonzero__', '__or__', '__pos__', '__pow__', '__radd__', '__rand__', '__rdivmod__', '__reduce__', '__reduce_ex__', '__repr__', '__rfloordiv__', '__rmatmul__', '__rmod__', '__rmu
# ...

# %%
# head() - returns first 5 records

df.head()
# Out:
#        Col 1  Col 2  Col 3  Col 4
# Row 1      1      2      3      4
# Row 2      2      3      6      4
# Row 3      9      7      8      6

# %%
df.head(2)
# Out:
#        Col 1  Col 2  Col 3  Col 4
# Row 1      1      2      3      4
# Row 2      2      3      6      4

# %%
# tail()

df.tail()
# Out:
#        Col 1  Col 2  Col 3  Col 4
# Row 1      1      2      3      4
# Row 2      2      3      6      4
# Row 3      9      7      8      6

# %%
df.tail(2)
# Out:
#        Col 1  Col 2  Col 3  Col 4
# Row 2      2      3      6      4
# Row 3      9      7      8      6

# %%
# loc - location

df.loc(0)

# %%
df.head().loc(0)

# %%
df.loc['Row 1']
# Out:
# Col 1    1
# Col 2    2
# Col 3    3
# Col 4    4
# Name: Row 1, dtype: int32

# %%
df.loc['Row 2']
# Out:
# Col 1    2
# Col 2    3
# Col 3    6
# Col 4    4
# Name: Row 2, dtype: int32

# %%
df.describe()
# Out:
#           Col 1     Col 2     Col 3     Col 4
# count  3.000000  3.000000  3.000000  3.000000
# mean   4.000000  4.000000  5.666667  4.666667
# std    4.358899  2.645751  2.516611  1.154701
# min    1.000000  2.000000  3.000000  4.000000
# 25%    1.500000  2.500000  4.500000  4.000000
# 50%    2.000000  3.000000  6.000000  4.000000
# 75%    5.500000  5.000000  7.000000  5.000000
# max    9.000000  7.000000  8.000000  6.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3 entries, Row 1 to Row 3
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Col 1   3 non-null      int32
#  1   Col 2   3 non-null      int32
#  2   Col 3   3 non-null      int32
#  3   Col 4   3 non-null      int32
# dtypes: int32(4)
# memory usage: 180.0+ bytes

# %%
df.columns
# Out:
# Index(['Col 1', 'Col 2', 'Col 3', 'Col 4'], dtype='object')

# %%
df.index
# Out:
# Index(['Row 1', 'Row 2', 'Row 3'], dtype='object')

# %%
df.dtypes
# Out:
# Col 1    int32
# Col 2    int32
# Col 3    int32
# Col 4    int32
# dtype: object

# %%
df.loc['Row 1']
# Out:
# Col 1    1
# Col 2    2
# Col 3    3
# Col 4    4
# Name: Row 1, dtype: int32

# %%
df.loc['Col 1']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Col 1'
#
# ...

# %%
# iloc

df.iloc

# %%
print(df.iloc.__doc__)
# Out:
# Purely integer-location based indexing for selection by position.
#
# ``.iloc[]`` is primarily integer position based (from ``0`` to
# ``length-1`` of the axis), but may also be used with a boolean
# array.
#
# Allowed inputs are:
#
# - An integer, e.g. ``5``.
# - A list or array of integers, e.g. ``[4, 3, 0]``.
# - A slice object with ints, e.g. ``1:7``.
# - A boolean array.
# - A ``callable`` function with one argument (the calling Series or
#   DataFrame) and that returns valid output for indexing (one of the above).
#   This is useful in method chains, when you don't have a reference to the
#   calling object, but would like to base your selection on some value.
# - A tuple of row and column indexes. The tuple elements consist of one of the
#   above inputs, e.g. ``(0, 1)``.
#
# ``.iloc`` will raise ``IndexError`` if a requested indexer is
# out-of-bounds, except *slice* indexers which allow out-of-bounds
# indexing (this conforms with python/numpy *slice* semantics).
#
# ...

# %%
df.iloc[[0]]
# Out:
#        Col 1  Col 2  Col 3  Col 4
# Row 1      1      2      3      4

# %%
df.iloc[0:1,]
# Out:
#        Col 1  Col 2  Col 3  Col 4
# Row 1      1      2      3      4

# %%
df.iloc[0:2,]
# Out:
#        Col 1  Col 2  Col 3  Col 4
# Row 1      1      2      3      4
# Row 2      2      3      6      4

# %%
df.loc[[1:2]]
# Out:
#   Cell In[58], line 1
#     df.loc[[1:2]]
#              ^
# SyntaxError: invalid syntax

# %%
# creating dataframe using dict

df = pd.DataFrame(
    {
        'a': [1,2,3],
        'b': [4,5,6],
        'c': [7,8,9]
    },
    index = [1,2,3]
)

# %%
df
# Out:
#    a  b  c
# 1  1  4  7
# 2  2  5  8
# 3  3  6  9

# %%
# specify values for each column

df = pd.DataFrame(
    [
        [1,2,3],
        [4,5,6],
        [7,8,9]
    ],
    index = [1,2,3],
    columns = ['a', 'b', 'c']
)

# %%
df
# Out:
#    a  b  c
# 1  1  2  3
# 2  4  5  6
# 3  7  8  9

# %%
df = pd.DataFrame(
    {
        'a': [1,2,3],
        'b': [4,5,6],
        'c': [7,8,9]
    },
    index = pd.MultiIndex.from_tuples(
        [
            ('d', 1),
            ('d', 2),
            ('e', 2)
        ], names = ['n', 'v']
    )
)

# %%
df
# Out:
#      a  b  c
# n v
# d 1  1  4  7
#   2  2  5  8
# e 2  3  6  9

# %%
df = pd.DataFrame(
    [
        [1,2,3],
        [4,5,6],
        [7,8,9]
    ],
    index = [1,2,3],
    columns = ['a', 'b', 'c']
)

# %%
df
# Out:
#    a  b  c
# 1  1  2  3
# 2  4  5  6
# 3  7  8  9

# %%
# Reshaping Data
# Gather columns into rows

pd.melt(df)
# Out:
#   variable  value
# 0        a      1
# 1        a      4
# 2        a      7
# 3        b      2
# 4        b      5
# 5        b      8
# 6        c      3
# 7        c      6
# 8        c      9

# %%
# Spread rows into columns.

df
# Out:
#    a  b  c
# 1  1  2  3
# 2  4  5  6
# 3  7  8  9

# %%
pd.melt(df)
# Out:
#   variable  value
# 0        a      1
# 1        a      4
# 2        a      7
# 3        b      2
# 4        b      5
# 5        b      8
# 6        c      3
# 7        c      6
# 8        c      9

# %%
pd.melt(df).var
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.var of   variable  value
# 0        a      1
# 1        a      4
# 2        a      7
# 3        b      2
# 4        b      5
# 5        b      8
# 6        c      3
# 7        c      6
# 8        c      9>

# %%
pd.melt(df).values
# Out:
# array([['a', 1],
#        ['a', 4],
#        ['a', 7],
#        ['b', 2],
#        ['b', 5],
#        ['b', 8],
#        ['c', 3],
#        ['c', 6],
#        ['c', 9]], dtype=object)

# %%
pd.melt(df)['variable']
# Out:
# 0    a
# 1    a
# 2    a
# 3    b
# 4    b
# 5    b
# 6    c
# 7    c
# 8    c
# Name: variable, dtype: object

# %%
pd.melt(df)['value']
# Out:
# 0    1
# 1    4
# 2    7
# 3    2
# 4    5
# 5    8
# 6    3
# 7    6
# 8    9
# Name: value, dtype: int64

# %%
pd.pivot(
    columns=pd.melt(df)['variable'],
    values=pd.melt(df)['value']
)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 pd.pivot(
#       2     columns=pd.melt(df)['variable'],
#       3     values=pd.melt(df)['value']
#       4 )
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# TypeError: pivot() missing 1 required positional argument: 'data'

# %%
pd.pivot(
    data=df,
    columns=pd.melt(df)['variable'],
    values=pd.melt(df)['value']
)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 pd.pivot(
#       2     data=df,
#       3     columns=pd.melt(df)['variable'],
#       4     values=pd.melt(df)['value']
#       5 )
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\reshape\pivot.py:533, in pivot(data, index, columns, values)
# ...

# %%
df = pd.DataFrame(
    {
        'a': [1,2,3],
        'b': [4,5,6],
        'c': [7,8,9]
    }
)

# %%
df
# Out:
#    a  b  c
# 0  1  4  7
# 1  2  5  8
# 2  3  6  9

# %%
df.pivot(index='a', columns='b', values='c')
# Out:
# b    4    5    6
# a
# 1  7.0  NaN  NaN
# 2  NaN  8.0  NaN
# 3  NaN  NaN  9.0

# %%
df = pd.DataFrame({'foo': ['one', 'one', 'one', 'two', 'two',
                           'two'],
                   'bar': ['A', 'B', 'C', 'A', 'B', 'C'],
                   'baz': [1, 2, 3, 4, 5, 6],
                   'zoo': ['x', 'y', 'z', 'q', 'w', 't']})

# %%
df
# Out:
#    foo bar  baz zoo
# 0  one   A    1   x
# 1  one   B    2   y
# 2  one   C    3   z
# 3  two   A    4   q
# 4  two   B    5   w
# 5  two   C    6   t

# %%
df.pivot(index='foo', columns='bar', values='baz')
# Out:
# bar  A  B  C
# foo
# one  1  2  3
# two  4  5  6

# %%
df = pd.DataFrame(
    {
        'a': [1,2,3],
        'b': [4,5,6],
        'c': [7,8,9]
    }
)

# %%
df
# Out:
#    a  b  c
# 0  1  4  7
# 1  2  5  8
# 2  3  6  9

# %%
df.a
# Out:
# 0    1
# 1    2
# 2    3
# Name: a, dtype: int64

# %%
df[df.a > 2]
# Out:
#    a  b  c
# 2  3  6  9

# %%
df.sample(frac=0.5)
# Out:
#    a  b  c
# 2  3  6  9
# 0  1  4  7

# %%
df['a']
# Out:
# 0    1
# 1    2
# 2    3
# Name: a, dtype: int64

# %%
df.describe()
# Out:
#          a    b    c
# count  3.0  3.0  3.0
# mean   2.0  5.0  8.0
# std    1.0  1.0  1.0
# min    1.0  4.0  7.0
# 25%    1.5  4.5  7.5
# 50%    2.0  5.0  8.0
# 75%    2.5  5.5  8.5
# max    3.0  6.0  9.0

# %%
# creating new column

df
# Out:
#    a  b  c
# 0  1  4  7
# 1  2  5  8
# 2  3  6  9

# %%
df['d'] = [77,88,99]

# %%
df
# Out:
#    a  b  c   d
# 0  1  4  7  77
# 1  2  5  8  88
# 2  3  6  9  99

# %%
# read csv

pd.read_csv("./pandas_csv/data.csv")
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130     409.1
# 1         60  '2020/12/02'    117       145     479.0
# 2         60  '2020/12/03'    103       135     340.0
# 3         45  '2020/12/04'    109       175     282.4
# 4         45  '2020/12/05'    117       148     406.0
# 5         60  '2020/12/06'    102       127     300.0
# 6         60  '2020/12/07'    110       136     374.0
# 7        450  '2020/12/08'    104       134     253.3
# 8         30  '2020/12/09'    109       133     195.1
# 9         60  '2020/12/10'     98       124     269.0
# 10        60  '2020/12/11'    103       147     329.3
# 11        60  '2020/12/12'    100       120     250.7
# 12        60  '2020/12/12'    100       120     250.7
# 13        60  '2020/12/13'    106       128     345.3
# 14        60  '2020/12/14'    104       132     379.3
# 15        60  '2020/12/15'     98       123     275.0
# ...

# %%
df = pd.read_csv("./pandas_csv/data.csv")

# %%
df.head()
# Out:
#    Duration          Date  Pulse  Maxpulse  Calories
# 0        60  '2020/12/01'    110       130     409.1
# 1        60  '2020/12/02'    117       145     479.0
# 2        60  '2020/12/03'    103       135     340.0
# 3        45  '2020/12/04'    109       175     282.4
# 4        45  '2020/12/05'    117       148     406.0

# %%
df.tail()
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 27        60  '2020/12/27'     92       118     241.0
# 28        60  '2020/12/28'    103       132       NaN
# 29        60  '2020/12/29'    100       132     280.0
# 30        60  '2020/12/30'    102       129     380.3
# 31        60  '2020/12/31'     92       115     243.0

# %%
df.Date
# Out:
# 0     '2020/12/01'
# 1     '2020/12/02'
# 2     '2020/12/03'
# 3     '2020/12/04'
# 4     '2020/12/05'
# 5     '2020/12/06'
# 6     '2020/12/07'
# 7     '2020/12/08'
# 8     '2020/12/09'
# 9     '2020/12/10'
# 10    '2020/12/11'
# 11    '2020/12/12'
# 12    '2020/12/12'
# 13    '2020/12/13'
# 14    '2020/12/14'
# 15    '2020/12/15'
# 16    '2020/12/16'
# 17    '2020/12/17'
# 18    '2020/12/18'
# 19    '2020/12/19'
# 20    '2020/12/20'
# 21    '2020/12/21'
# 22             NaN
# 23    '2020/12/23'
# 24    '2020/12/24'
# 25    '2020/12/25'
# 26        20201226
# 27    '2020/12/27'
# 28    '2020/12/28'
# 29    '2020/12/29'
# 30    '2020/12/30'
# 31    '2020/12/31'
# Name: Date, dtype: object

# %%
df.isnull()
# Out:
#     Duration   Date  Pulse  Maxpulse  Calories
# 0      False  False  False     False     False
# 1      False  False  False     False     False
# 2      False  False  False     False     False
# 3      False  False  False     False     False
# 4      False  False  False     False     False
# 5      False  False  False     False     False
# 6      False  False  False     False     False
# 7      False  False  False     False     False
# 8      False  False  False     False     False
# 9      False  False  False     False     False
# 10     False  False  False     False     False
# 11     False  False  False     False     False
# 12     False  False  False     False     False
# 13     False  False  False     False     False
# 14     False  False  False     False     False
# 15     False  False  False     False     False
# 16     False  False  False     False     False
# 17     False  False  False     False     False
# 18     False  False  False     False      True
# ...

# %%
df.Date.isnull()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22     True
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# Name: Date, dtype: bool

# %%
df.isna()
# Out:
#     Duration   Date  Pulse  Maxpulse  Calories
# 0      False  False  False     False     False
# 1      False  False  False     False     False
# 2      False  False  False     False     False
# 3      False  False  False     False     False
# 4      False  False  False     False     False
# 5      False  False  False     False     False
# 6      False  False  False     False     False
# 7      False  False  False     False     False
# 8      False  False  False     False     False
# 9      False  False  False     False     False
# 10     False  False  False     False     False
# 11     False  False  False     False     False
# 12     False  False  False     False     False
# 13     False  False  False     False     False
# 14     False  False  False     False     False
# 15     False  False  False     False     False
# 16     False  False  False     False     False
# 17     False  False  False     False     False
# 18     False  False  False     False      True
# ...

# %%
# drop(column)

df.drop('Date', axis=1)
# Out:
#     Duration  Pulse  Maxpulse  Calories
# 0         60    110       130     409.1
# 1         60    117       145     479.0
# 2         60    103       135     340.0
# 3         45    109       175     282.4
# 4         45    117       148     406.0
# 5         60    102       127     300.0
# 6         60    110       136     374.0
# 7        450    104       134     253.3
# 8         30    109       133     195.1
# 9         60     98       124     269.0
# 10        60    103       147     329.3
# 11        60    100       120     250.7
# 12        60    100       120     250.7
# 13        60    106       128     345.3
# 14        60    104       132     379.3
# 15        60     98       123     275.0
# 16        60     98       120     215.2
# 17        60    100       120     300.0
# 18        45     90       112       NaN
# 19        60    103       123     323.0
# 20        45     97       125     243.0
# 21        60    108       131     364.2
# ...

# %%
df.head()
# Out:
#    Duration          Date  Pulse  Maxpulse  Calories
# 0        60  '2020/12/01'    110       130     409.1
# 1        60  '2020/12/02'    117       145     479.0
# 2        60  '2020/12/03'    103       135     340.0
# 3        45  '2020/12/04'    109       175     282.4
# 4        45  '2020/12/05'    117       148     406.0

# %%
print(df.drop.__doc__)
# Out:
#         Drop specified labels from rows or columns.
#
#         Remove rows or columns by specifying label names and corresponding
#         axis, or by specifying directly index or column names. When using a
#         multi-index, labels on different levels can be removed by specifying
#         the level. See the `user guide <advanced.shown_levels>`
#         for more information about the now unused levels.
#
#         Parameters
#         ----------
#         labels : single label or list-like
#             Index or column labels to drop. A tuple will be used as a single
#             label and not treated as a list-like.
#         axis : {0 or 'index', 1 or 'columns'}, default 0
#             Whether to drop labels from the index (0 or 'index') or
#             columns (1 or 'columns').
#         index : single label or list-like
#             Alternative to specifying axis (``labels, axis=0``
#             is equivalent to ``index=labels``).
# ...

# %%
df.count()
# Out:
# Duration    32
# Date        31
# Pulse       32
# Maxpulse    32
# Calories    30
# dtype: int64

# %%
df.tail()
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 27        60  '2020/12/27'     92       118     241.0
# 28        60  '2020/12/28'    103       132       NaN
# 29        60  '2020/12/29'    100       132     280.0
# 30        60  '2020/12/30'    102       129     380.3
# 31        60  '2020/12/31'     92       115     243.0

# %%
# dropna()

df.dropna()
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130     409.1
# 1         60  '2020/12/02'    117       145     479.0
# 2         60  '2020/12/03'    103       135     340.0
# 3         45  '2020/12/04'    109       175     282.4
# 4         45  '2020/12/05'    117       148     406.0
# 5         60  '2020/12/06'    102       127     300.0
# 6         60  '2020/12/07'    110       136     374.0
# 7        450  '2020/12/08'    104       134     253.3
# 8         30  '2020/12/09'    109       133     195.1
# 9         60  '2020/12/10'     98       124     269.0
# 10        60  '2020/12/11'    103       147     329.3
# 11        60  '2020/12/12'    100       120     250.7
# 12        60  '2020/12/12'    100       120     250.7
# 13        60  '2020/12/13'    106       128     345.3
# 14        60  '2020/12/14'    104       132     379.3
# 15        60  '2020/12/15'     98       123     275.0
# ...

# %%
df.dropna().count()
# Out:
# Duration    29
# Date        29
# Pulse       29
# Maxpulse    29
# Calories    29
# dtype: int64

# %%
# fillna(value)

df.fillna(1000)
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130     409.1
# 1         60  '2020/12/02'    117       145     479.0
# 2         60  '2020/12/03'    103       135     340.0
# 3         45  '2020/12/04'    109       175     282.4
# 4         45  '2020/12/05'    117       148     406.0
# 5         60  '2020/12/06'    102       127     300.0
# 6         60  '2020/12/07'    110       136     374.0
# 7        450  '2020/12/08'    104       134     253.3
# 8         30  '2020/12/09'    109       133     195.1
# 9         60  '2020/12/10'     98       124     269.0
# 10        60  '2020/12/11'    103       147     329.3
# 11        60  '2020/12/12'    100       120     250.7
# 12        60  '2020/12/12'    100       120     250.7
# 13        60  '2020/12/13'    106       128     345.3
# 14        60  '2020/12/14'    104       132     379.3
# 15        60  '2020/12/15'     98       123     275.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Duration  32 non-null     int64
#  1   Date      31 non-null     object
#  2   Pulse     32 non-null     int64
#  3   Maxpulse  32 non-null     int64
#  4   Calories  30 non-null     float64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 1.4+ KB

# %%
df.describe()
# Out:
#          Duration       Pulse    Maxpulse    Calories
# count   32.000000   32.000000   32.000000   30.000000
# mean    68.437500  103.500000  128.500000  304.680000
# std     70.039591    7.832933   12.998759   66.003779
# min     30.000000   90.000000  101.000000  195.100000
# 25%     60.000000  100.000000  120.000000  250.700000
# 50%     60.000000  102.500000  127.500000  291.200000
# 75%     60.000000  106.500000  132.250000  343.975000
# max    450.000000  130.000000  175.000000  479.000000

# %%
df["Calories"].mean()
# Out:
# 304.68

# %%
df["Calories"].fillna(df["Calories"].mean())
# Out:
# 0     409.10
# 1     479.00
# 2     340.00
# 3     282.40
# 4     406.00
# 5     300.00
# 6     374.00
# 7     253.30
# 8     195.10
# 9     269.00
# 10    329.30
# 11    250.70
# 12    250.70
# 13    345.30
# 14    379.30
# 15    275.00
# 16    215.20
# 17    300.00
# 18    304.68
# 19    323.00
# 20    243.00
# 21    364.20
# 22    282.00
# 23    300.00
# 24    246.00
# 25    334.50
# 26    250.00
# 27    241.00
# 28    304.68
# 29    280.00
# 30    380.30
# 31    243.00
# Name: Calories, dtype: float64

# %%
# rectify wrong format

pd.to_datetime(df['Date'])
# Out:
# 0    2020-12-01
# 1    2020-12-02
# 2    2020-12-03
# 3    2020-12-04
# 4    2020-12-05
# 5    2020-12-06
# 6    2020-12-07
# 7    2020-12-08
# 8    2020-12-09
# 9    2020-12-10
# 10   2020-12-11
# 11   2020-12-12
# 12   2020-12-12
# 13   2020-12-13
# 14   2020-12-14
# 15   2020-12-15
# 16   2020-12-16
# 17   2020-12-17
# 18   2020-12-18
# 19   2020-12-19
# 20   2020-12-20
# 21   2020-12-21
# 22          NaT
# 23   2020-12-23
# 24   2020-12-24
# 25   2020-12-25
# 26   2020-12-26
# 27   2020-12-27
# 28   2020-12-28
# 29   2020-12-29
# 30   2020-12-30
# 31   2020-12-31
# Name: Date, dtype: datetime64[ns]

# %%
df.loc[7, 'Duration']
# Out:
# 450

# %%
df.loc[7, 'Duration'] = 30

# %%
df
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130     409.1
# 1         60  '2020/12/02'    117       145     479.0
# 2         60  '2020/12/03'    103       135     340.0
# 3         45  '2020/12/04'    109       175     282.4
# 4         45  '2020/12/05'    117       148     406.0
# 5         60  '2020/12/06'    102       127     300.0
# 6         60  '2020/12/07'    110       136     374.0
# 7         30  '2020/12/08'    104       134     253.3
# 8         30  '2020/12/09'    109       133     195.1
# 9         60  '2020/12/10'     98       124     269.0
# 10        60  '2020/12/11'    103       147     329.3
# 11        60  '2020/12/12'    100       120     250.7
# 12        60  '2020/12/12'    100       120     250.7
# 13        60  '2020/12/13'    106       128     345.3
# 14        60  '2020/12/14'    104       132     379.3
# 15        60  '2020/12/15'     98       123     275.0
# ...

# %%
# remove duplicates

df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12     True
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# dtype: bool
